# %%
import cv2
import numpy as np
from sklearn.metrics import pairwise_distances
from sklearn.metrics.pairwise import pairwise_kernels
from sklearn.metrics.pairwise import euclidean_distances
import matplotlib.pyplot  as plt
import os

# %%
def cosinesimilairty(X,Y):
    x1 = pairwise_kernels(X, Y, metric='linear')
    x1 = x1.mean()
    # x2 = pairwise_kernels(X, Y, metric='manhattan')
    x3 = euclidean_distances(X, Y)
    x3 = x3.mean()
    output = [x1,x3]
    return output

# %%
img1 = cv2.imread("./data/colours/black/1598727943.854497.jpg")

# %%
# img2 = cv2.imread("./data/3/1598727859.1135302.jpg")

# %%
img2 = cv2.imread("./data/4/1598727943.854497.jpg")

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1.ravel().reshape(1,-1).shape
# Out:
# (1, 12000)

# %%
cosinesimilairty(img1.ravel().reshape(1,-1),img2.ravel().reshape(1,-1))
# Out:
# [35153469.0, 3769.175771969251]

# %%
def similarity(folder,refId):
    data = []
#     refImg = cv2.imread(folder+os.listdir(folder)[refId])
    refImg = img1
    
    print(cv2.merge([cv2.split(refImg)[2],cv2.split(refImg)[1],cv2.split(refImg)[0]]).shape)
    plt.imshow(cv2.merge([cv2.split(refImg)[2],cv2.split(refImg)[1],cv2.split(refImg)[0]]))
#     refImg = refImg[5:-10,:]
    for i in os.listdir(folder):
        img = cv2.imread(folder+i)
#         img = img[5:-10,:]
        sim = cosinesimilairty(refImg.ravel().reshape(1,-1),img.ravel().reshape(1,-1))[1]
    #     print(sim)
        data.append(sim)
    data = np.asarray(data) 
    print("mean: ",data.mean())
    print("std: ",data.std())
    print("data of first 10 cops " , [j for j in data[:10]])

# %%
similarity("./data/colours/dblue/",0)
# Out:
# (25, 160, 3)
# mean:  3976.985993888076
# std:  705.2815140120383
# data of first 10 cops  [3813.012457362289, 4414.692401515648, 4785.83503685616, 3953.5537178594145, 3239.2974546960027, 4828.032207846174, 4785.83503685616, 4788.194127225837, 3973.4273618628035, 4139.889249726374]

# %%
similarity("./data/colours/black/",0)
# Out:
# (25, 160, 3)
# mean:  2556.9727884823087
# std:  1137.333002669406
# data of first 10 cops  [1407.579127438312, 0.0, 4415.637553060713, 1688.5212465349673, 2034.7673085638073, 1256.2432089368683, 2294.672743551899, 3250.8071305446592, 2212.5566659410106, 4076.292923723711]

# %%
similarity("./data/colours/orange/",1)
# Out:
# (25, 160, 3)
# mean:  6114.230656666364
# std:  313.5656662984721
# data of first 10 cops  [5890.044397116205, 5865.684870498926, 6492.895579015575, 5929.461695634774, 5808.737900783612, 6402.487172966456, 5559.74864539756, 6541.487674833607, 5772.560696952437, 6087.258003403503]

# %%
similarity("./data/colours/violet/",0)
# Out:
# (25, 160, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-185-1a72f83ba854> in <module>
# ----> 1 similarity("./data/colours/violet/",0)
#
# <ipython-input-180-92cd63687daf> in similarity(folder, refId)
#      10         img = cv2.imread(folder+i)
#      11 #         img = img[5:-10,:]
# ---> 12         sim = cosinesimilairty(refImg.ravel().reshape(1,-1),img.ravel().reshape(1,-1))[1]
#      13     #     print(sim)
#      14         data.append(sim)
#
# <ipython-input-51-94cc46ab5764> in cosinesimilairty(X, Y)
#       1 def cosinesimilairty(X,Y):
# ----> 2     x1 = pairwise_kernels(X, Y, metric='linear')
#       3     x1 = x1.mean()
#       4     # x2 = pairwise_kernels(X, Y, metric='manhattan')
#       5     x3 = euclidean_distances(X, Y)
#
# ~/playground/ml/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
# ...

# %%
similarity("./data/colours/lgreen/",0)
# Out:
# (25, 160, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-186-a7a76ead128a> in <module>
# ----> 1 similarity("./data/colours/lgreen/",0)
#
# <ipython-input-180-92cd63687daf> in similarity(folder, refId)
#      10         img = cv2.imread(folder+i)
#      11 #         img = img[5:-10,:]
# ---> 12         sim = cosinesimilairty(refImg.ravel().reshape(1,-1),img.ravel().reshape(1,-1))[1]
#      13     #     print(sim)
#      14         data.append(sim)
#
# <ipython-input-51-94cc46ab5764> in cosinesimilairty(X, Y)
#       1 def cosinesimilairty(X,Y):
# ----> 2     x1 = pairwise_kernels(X, Y, metric='linear')
#       3     x1 = x1.mean()
#       4     # x2 = pairwise_kernels(X, Y, metric='manhattan')
#       5     x3 = euclidean_distances(X, Y)
#
# ~/playground/ml/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
# ...

# %%
similarity("./data/colours/blue/",0)
# Out:
# (20, 120, 3)
# mean:  1332.1306856266249
# std:  874.3728246074087
# data of first 10 cops  [0.0, 1891.5789700670707, 653.9495393377076, 2391.218308728837, 1723.9066099995093]

# %%
plt.imshow(cv2.merge([cv2.split(img1)[2],cv2.split(img1)[1],cv2.split(img1)[0]]))

# %%
similarity("./data/colours/dblue/",0)
# Out:
# (25, 160, 3)
# mean:  3976.985993888076
# std:  705.2815140120383
# data of first 10 cops  [3813.012457362289, 4414.692401515648, 4785.83503685616, 3953.5537178594145, 3239.2974546960027, 4828.032207846174, 4785.83503685616, 4788.194127225837, 3973.4273618628035, 4139.889249726374]
