# %%
import cv2
import numpy as np
from sklearn.metrics import pairwise_distances
from sklearn.metrics.pairwise import pairwise_kernels
from sklearn.metrics.pairwise import euclidean_distances
import matplotlib.pyplot  as plt
import os

# %%
def cosinesimilairty(X,Y):
    x1 = pairwise_kernels(X, Y, metric='linear')
    x1 = x1.mean()
    # x2 = pairwise_kernels(X, Y, metric='manhattan')
    x3 = euclidean_distances(X, Y)
    x3 = x3.mean()
    output = [x1,x3]
    return output

# %%
img1 = cv2.imread("./data/3/1598727723.502699.jpg")

# %%
# img2 = cv2.imread("./data/3/1598727859.1135302.jpg")

# %%
img2 = cv2.imread("./data/4/1598727943.854497.jpg")

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1.ravel().reshape(1,-1).shape
# Out:
# (1, 12000)

# %%
cosinesimilairty(img1.ravel().reshape(1,-1),img2.ravel().reshape(1,-1))
# Out:
# [35153469.0, 3769.175771969251]

# %%
def similarity(folder,refId):
    data = []
#     refImg = cv2.imread(folder+os.listdir(folder)[refId])
    
    print(cv2.merge([cv2.split(refImg)[2],cv2.split(refImg)[1],cv2.split(refImg)[0]]).shape)
    plt.imshow(cv2.merge([cv2.split(refImg)[2],cv2.split(refImg)[1],cv2.split(refImg)[0]]))
#     refImg = refImg[5:-10,:]
    for i in os.listdir(folder):
        img = cv2.imread(folder+i)
#         img = img[5:-10,:]
        sim = cosinesimilairty(refImg.ravel().reshape(1,-1),img.ravel().reshape(1,-1))[1]
    #     print(sim)
        data.append(sim)
    data = np.asarray(data) 
    print("mean: ",data.mean())
    print("std: ",data.std())
    print("data of first 10 cops " , [j for j in data[:10]])

# %%
similarity("./data/colours/dblue/",0)
# Out:
# (25, 160, 3)
# mean:  1982.699843365743
# std:  685.2733898151108
# data of first 10 cops  [0.0, 2175.211024245694, 2643.7437470375226, 1531.1136469903206, 2229.968161207689, 3340.2318781785193, 2643.7437470375226, 2484.252201367647, 1582.3264517791517, 1352.593434850251]

# %%
similarity("./data/colours/black/",0)
# Out:
# (25, 160, 3)
# mean:  2184.9044061783106
# std:  1168.9530084064977
# data of first 10 cops  [0.0, 1407.579127438312, 4116.511387084943, 1432.3885646011001, 1059.7891299687876, 884.1108527780891, 2167.712158013605, 2886.693956760917, 2002.3890730824517, 3779.327056500932]

# %%
similarity("./data/colours/orange/",1)
# Out:
# (25, 160, 3)
# mean:  2656.2686696482965
# std:  707.9541684635162
# data of first 10 cops  [3517.4072837816207, 0.0, 3512.1255672313314, 2424.328154355346, 2768.793780692235, 3335.059369786391, 1712.6675100555858, 2751.700201693491, 3185.035321625178, 3123.4735471906915]

# %%
similarity("./data/colours/violet/",0)
# Out:
# (20, 120, 3)
# mean:  1753.3278114117045
# std:  976.210523263421
# data of first 10 cops  [0.0, 1979.9590904864676, 1509.4621558687718, 2559.554844108639, 2717.662966594644]

# %%
similarity("./data/colours/lgreen/",0)
# Out:
# (20, 120, 3)
# mean:  2103.4658290591638
# std:  1366.1525924948667
# data of first 10 cops  [0.0, 991.1109927752794, 3493.5639395894846, 3204.6865681373583, 2827.9676447936954]

# %%
similarity("./data/colours/blue/",0)
# Out:
# (20, 120, 3)
# mean:  1332.1306856266249
# std:  874.3728246074087
# data of first 10 cops  [0.0, 1891.5789700670707, 653.9495393377076, 2391.218308728837, 1723.9066099995093]

# %%
similarity("./data/colours/dblue/",0)
